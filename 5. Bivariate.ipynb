# %%
import pandas as pd

# %%
dataset=pd.read_csv("preplacement.csv")

# %%
dataset
# Out:
#      Unnamed: 0  sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary  \
# 0             0    1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1             1    2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2             2    3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3             3    4.0  56.00  52.00     52.00     66.0  59.43  265000.0
# 4             4    5.0  85.80  73.60     73.30     96.8  55.50  390000.0
# ..          ...    ...    ...    ...       ...      ...    ...       ...
# 210         210  211.0  80.60  82.00     77.60     91.0  74.49  390000.0
# 211         211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0
# 212         212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0
# 213         213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0
# 214         214  215.0  62.00  58.00     53.00     89.0  60.22  265000.0
#
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0        0
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %% [markdown]
# # covariance

# %%
dataset.drop(["sl_no","Unnamed: 0"],inplace=True,axis=1)

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43  265000.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  390000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  390000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22  265000.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset.cov()
# Out:
#                  ssc_p         hsc_p      degree_p        etest_p  \
# ssc_p       117.228377     58.853253     42.702550      37.659225
# hsc_p        58.853253    112.063731     33.684453      33.838355
# degree_p     42.702550     33.684453     53.604710      22.078774
# etest_p      37.659225     33.838355     22.078774     176.251018
# mba_p        24.535952     21.517688     17.185200      16.886973
# salary    85586.186481  61023.359270  30477.753097  139456.612910
#
#                  mba_p        salary
# ssc_p        24.535952  8.558619e+04
# hsc_p        21.517688  6.102336e+04
# degree_p     17.185200  3.047775e+04
# etest_p      16.886973  1.394566e+05
# mba_p        34.028376  5.157554e+04
# salary    51575.540752  2.057171e+09

# %%
### difference between the degree and etest pass mark are 21.92 
### difference between the etest and mba pass mwrk are 16.89

# %%
dataset.corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.513478  0.538686  0.261993  0.388478  0.174282
# hsc_p     0.513478  1.000000  0.434606  0.240775  0.348452  0.127095
# degree_p  0.538686  0.434606  1.000000  0.227147  0.402376  0.091780
# etest_p   0.261993  0.240775  0.227147  1.000000  0.218055  0.231600
# mba_p     0.388478  0.348452  0.402376  0.218055  1.000000  0.194934
# salary    0.174282  0.127095  0.091780  0.231600  0.194934  1.000000

# %%
### relationship between the mba pass mark and salary are 0.14 precent

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %% [markdown]
# # variance inflation factor

# %%
def Quanqual(dataset):
    qual=[]
    quan=[]
    for columnName in dataset.columns:
        if (dataset[columnName].dtypes=="O"):
            qual.append(columnName)
        else:
            quan.append(columnName)
    return qual,quan

# %%
qual,quan=Quanqual(dataset)

# %%
df=dataset[quan]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):
    vif=pd.DataFrame()
    vif["variables"]=X.columns
    vif["VIF"]=[variance_inflation_factor(X.values,i)for i in range(X.shape[1])]
    return(vif)

# %%
calc_vif(df)
# Out:
#   variables         VIF
# 0     ssc_p   67.341035
# 1     hsc_p   59.149652
# 2  degree_p  114.371985
# 3   etest_p   34.543707
# 4     mba_p  111.806834
# 5    salary   37.714260

# %% [markdown]
# ### independent -- unpaired ttest
# differance group and same conditions

# %%
from scipy.stats import ttest_ind
Male = dataset[dataset['gender']=="M"]["salary"]
Female = dataset[dataset['gender']=="F"]["salary"]
ttest_ind(Male , Female)
# Out:
# Ttest_indResult(statistic=2.629677683075146, pvalue=0.009170024182161505)

# %%
from scipy.stats import ttest_ind
centrals=dataset[dataset['ssc_b']=="Central"]["salary"]
others=dataset[dataset['ssc_b']=="Others"]["salary"]
ttest_ind(centrals,others)
# Out:
# Ttest_indResult(statistic=-1.1715403808648728, pvalue=0.24269045942986298)

# %% [markdown]
# ### dependent -- paired ttest
# same group and different conditions

# %%
from scipy.stats import ttest_rel
Other_s=dataset[dataset['ssc_b']=="Others"]["ssc_p"]
Other_h=dataset[dataset['ssc_b']=="Others"]["hsc_p"]
ttest_rel(Other_s,Other_h)
# Out:
# Ttest_relResult(statistic=3.699619007465292, pvalue=0.0003564874201816981)

# %%
from scipy.stats import ttest_rel
Notplacement_s=dataset[dataset['status']=='Not Placed']["ssc_p"]
Notplacement_h=dataset[dataset['status']=='Not Placed']["hsc_p"]
ttest_rel(Notplacement_s,Notplacement_h)
# Out:
# Ttest_relResult(statistic=-0.8327045813635164, pvalue=0.40801450944785744)

# %% [markdown]
# # analysis of variances

# %%
#one way analysis
import scipy.stats as stats
stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=17.41041100562955, pvalue=4.331943257679767e-08)

# %%
df=dataset[dataset['status']=='Not Placed']

# %%
df
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 3     56.0  52.00     52.00    66.00  59.43  265000.0      M  Central
# 5     55.0  49.80     67.25    55.00  51.58  265000.0      M   Others
# 6     46.0  49.20     79.00    74.28  53.29  265000.0      F   Others
# 9     58.0  70.00     61.00    54.00  52.21  265000.0      M  Central
# 12    47.0  55.00     65.00    62.00  65.04  265000.0      F  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 198   67.0  70.00     65.00    88.00  71.96  265000.0      F  Central
# 201   54.2  63.00     58.00    79.00  58.44  265000.0      M  Central
# 206   41.0  42.75     60.00    97.00  53.39  265000.0      M  Central
# 208   43.0  60.00     65.00    92.66  62.92  265000.0      F  Central
# 214   62.0  58.00     53.00    89.00  60.22  265000.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(data=df,x="ssc_p")
plt.title("Distribution of ssc score for not placement students")
plt.show()

# %%
sns.histplot(data=df,x="hsc_p")
plt.title("Distribution of hsc score for not placement students")
plt.show()

# %%
sns.histplot(data=df,x="degree_p")
plt.title("Distribution of degree score for not placement students")
plt.show()

# %%
sns.histplot(data=df,x="etest_p")
plt.title("Distribution of etest score for not placement students")
plt.show()

# %%
sns.histplot(data=df,x="mba_p")
plt.title("Distribution of mba score for not placement students")
plt.show()
